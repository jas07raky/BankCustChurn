# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
cust_data = pd.read_csv('/Users/sweathanjasty/Desktop/Springboard/Bankchurners.csv')

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
cust_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
missing = pd.concat([cust_data.isnull().sum(), 100 * cust_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                                                     count    %
# CLIENTNUM                                               0  0.0
# Avg_Utilization_Ratio                                   0  0.0
# Total_Ct_Chng_Q4_Q1                                     0  0.0
# Total_Trans_Ct                                          0  0.0
# Total_Trans_Amt                                         0  0.0
# Total_Amt_Chng_Q4_Q1                                    0  0.0
# Avg_Open_To_Buy                                         0  0.0
# Total_Revolving_Bal                                     0  0.0
# Credit_Limit                                            0  0.0
# Contacts_Count_12_mon                                   0  0.0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Cate...      0  0.0
# Months_Inactive_12_mon                                  0  0.0
# Months_on_book                                          0  0.0
# Card_Category                                           0  0.0
# ...

# %%
## No missing values in the data

# %%
cust_data.drop(columns='Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', inplace=True)

# %%
cust_data.drop(columns='Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2', inplace=True)

# %%
##Dropped Naive Bayes Classifier Columns

# %%
cust_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
##Checking categorical Variables

cust_data.select_dtypes('object')
# Out:
#           Attrition_Flag Gender Education_Level Marital_Status  \
# 0      Existing Customer      M     High School        Married
# 1      Existing Customer      F        Graduate         Single
# 2      Existing Customer      M        Graduate        Married
# 3      Existing Customer      F     High School        Unknown
# 4      Existing Customer      M      Uneducated        Married
# ...                  ...    ...             ...            ...
# 10122  Existing Customer      M        Graduate         Single
# 10123  Attrited Customer      M         Unknown       Divorced
# 10124  Attrited Customer      F     High School        Married
# 10125  Attrited Customer      M        Graduate        Unknown
# 10126  Attrited Customer      F        Graduate        Married
#
#       Income_Category Card_Category
# 0         $60K - $80K          Blue
# 1      Less than $40K          Blue
# 2        $80K - $120K          Blue
# 3      Less than $40K          Blue
# ...

# %%
## Plots for different categorical features

#Create two subplots on 1 row and 2 columns with a figsize of (12, 8)
fig, ax = plt.subplots(1, 2, figsize=(12,8))
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Attrition_Flag.value_counts().plot(kind='barh', ax=ax[0])
#Give the plot a helpful title of 'Region'
ax[0].set_title('Attrition_Flag')
#Label the xaxis 'Count'
ax[0].set_xlabel('Count')
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Gender.value_counts().plot(kind='barh', ax=ax[1])
#Give the plot a helpful title of 'state'
ax[1].set_title('Gender')
#Label the xaxis 'Count'
ax[1].set_xlabel('Count')
#Give the subplots a little "breathing room" with a wspace of 0.5
plt.subplots_adjust(wspace=0.5);


fig, ax = plt.subplots(1, 2, figsize=(12,8))
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Education_Level.value_counts().plot(kind='barh', ax=ax[0])
#Give the plot a helpful title of 'Region'
ax[0].set_title('Education_Level')
#Label the xaxis 'Count'
ax[0].set_xlabel('Count')
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Marital_Status.value_counts().plot(kind='barh', ax=ax[1])
#Give the plot a helpful title of 'state'
ax[1].set_title('Marital_Status')
#Label the xaxis 'Count'
ax[1].set_xlabel('Count')
#Give the subplots a little "breathing room" with a wspace of 0.5
plt.subplots_adjust(wspace=0.5);


fig, ax = plt.subplots(1, 2, figsize=(12,8))
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Income_Category.value_counts().plot(kind='barh', ax=ax[0])
#Give the plot a helpful title of 'Region'
ax[0].set_title('Income_Category')
#Label the xaxis 'Count'
ax[0].set_xlabel('Count')
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
cust_data.Card_Category.value_counts().plot(kind='barh', ax=ax[1])
#Give the plot a helpful title of 'state'
ax[1].set_title('Card_Category')
#Label the xaxis 'Count'
ax[1].set_xlabel('Count')
#Give the subplots a little "breathing room" with a wspace of 0.5
plt.subplots_adjust(wspace=0.5);

# %%
## Pie Charts for Categorical Variables 

fig, ax = plt.subplots(figsize=(7, 7))
count = Counter(y)
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title('Percentage of existing and attrited/churned customers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-146fa83a3906> in <module>
#       2
#       3 fig, ax = plt.subplots(figsize=(7, 7))
# ----> 4 count = Counter(y)
#       5 ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
#       6 ax.set_title('Percentage of existing and attrited/churned customers')
#
# NameError: name 'Counter' is not defined
